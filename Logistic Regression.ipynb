# %% [markdown]
# ## Logistic Regression:
# - Logistic Regression is a supervised machine learning algorithm used for classification, prredicting the probobility of a categorical outcome (like yes/no, spam/not spam) by fitting data to a sigmoid (S-shaped) curve, which maps linear combinations of features to probabilities between zero and one.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data = pd.DataFrame({
    "hours_studied": [1,2,3,4,5],
    "result": [0,0,0,1,1]
})
data
# Out:
#    hours_studied  result
# 0              1       0
# 1              2       0
# 2              3       0
# 3              4       1
# 4              5       1

# %%
x = data[["hours_studied"]]
y = data["result"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion_matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Confusion_matrix:
#  [[1]]

# %%
hours = [[6]]
prediction = model.predict(hours)
probability = model.predict_proba(hours)

print("Prediction:", prediction)
print("Probability:", probability)
# Out:
# Prediction: [1]
# Probability: [[0.07958121 0.92041879]]
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
print("w0 (intercept):", model.intercept_)
print("w1 (coefficient):", model.coef_)
# Out:
# w0 (intercept): [-3.05864888]
# w1 (coefficient): [[0.91778327]]

# %%
probs = probability[0]
classes = ['Fail', 'Pass']

plt.figure()
plt.bar(classes,probs)
plt.xlabel('class')
plt.ylabel('probability')
plt.title('Prediction Proability')
plt.show()
